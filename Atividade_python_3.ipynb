# %% [markdown]
# <a href="https://colab.research.google.com/github/alicevitoria4177-arch/-atividade-python/blob/main/Atividade_python_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
soma = 0
aprovados = 0
abaixo = 0

for i in range(5)
  nota = float(input("Nota: "))
  soma += nota
  if nota >=7:
   aprovados += 1
  else:
   abaixo +=1
media = soma / 5
print("Media: ",media)
print("Notas > 7: ",aprovados)
print("Notas < 7: ",abaixo)

# %%
primeiro = int(input("digite um numero: "))
maior = primeiro
menor = primeiro
for i in range(5):
  numero = int(input("digite um numero: "))
  if  numero > maior:
    maior = numero
  if numero < menor:
    menor = numero
    print("Maior: ",maior)
    print("Menor: ",menor)

# %%
nota = float(input("notas entre 0 e 10: "))
while nota < 0 or nota >10:
  print("nota invalida")
  nota = float(input("digite novamente"))

  print("nota valida: ",nota)
