# %% [markdown]
# <a href="https://colab.research.google.com/github/alicevitoria4177-arch/-atividade-python/blob/main/Atividade4_1python_(104_A)_Viroria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# QUESTÃO 1

# %%
notas = []

for i in range(5):
  nota = float(input("Digite a nota: "))
  notas.append(nota)

soma = 0
for notas in notas:
  soma += nota

media = soma / len(notas)
acima_ou_igual = 0
for notas in notas:
  if nota >= media:
    acima_ou_igual += 1
    print("Notas: ",notas)
    print("Media: ",media)
    print("Notas >= media: ",acima_ou_igual)
# Out:
# Digite a nota: 6
# Digite a nota: 7
# Digite a nota: 8
# Digite a nota: 9
# Digite a nota: 6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3440/1872974044.py in <cell line: 0>()
#       9   soma += nota
#      10
# ---> 11 media = soma / len(notas)
#      12 acima_ou_igual = 0
#      13 for notas in notas:
#
# TypeError: object of type 'float' has no len()

# %% [markdown]
# QUESTÃO 2

# %% [markdown]
# QUESTÃO 3

# %% [markdown]
# QUESTÃO 4

# %%
numeros = []
for i in range(10):
    num = int(input(f"Digite o {i+1}º número: "))
    numeros.append(num)

pares = []
impares = []

for num in numeros:
    if num % 2 == 0:
        pares.append(num)
    else:
        impares.append(num)

print(f"Lista completa: {numeros}")
print(f"Pares: {pares}")
print(f"Ímpares: {impares}")
# Out:
# Digite o 1º número: 8
# Digite o 2º número: 7
# Digite o 3º número: 8
# Digite o 4º número: 6
# Digite o 5º número: 45
# Digite o 6º número: 34
# Digite o 7º número: 3
# Digite o 8º número: 2
# Digite o 9º número: 7
# Digite o 10º número: 0
# Lista completa: [8, 7, 8, 6, 45, 34, 3, 2, 7, 0]
# Pares: [8, 8, 6, 34, 2, 0]
# Ímpares: [7, 45, 3, 7]

# %% [markdown]
# QUESTÃO 5

# %%
numeros = []
for i in range(8):
    num = int(input(f"Digite o {i+1}º número: "))
    numeros.append(num)

maior = numeros[0]
menor = numeros[0]
pos_maior = 0
pos_menor = 0

for i in range(1, len(numeros)):
    if numeros[i] > maior:
        maior = numeros[i]
        pos_maior = i
    if numeros[i] < menor:
        menor = numeros[i]
        pos_menor = i

print(f"Maior valor: {maior} (primeira ocorrência no índice {pos_maior})")
print(f"Menor valor: {menor} (primeira ocorrência no índice {pos_menor})")
# Out:
# Digite o 1º número: 5
# Digite o 2º número: 6
# Digite o 3º número: 5
# Digite o 4º número: 4
# Digite o 5º número: 3
# Digite o 6º número: 2
# Digite o 7º número: 9
# Digite o 8º número: 8
# Maior valor: 9 (primeira ocorrência no índice 6)
# Menor valor: 2 (primeira ocorrência no índice 5)

# %% [markdown]
# QUESTÃO 6

# %%
nomes = []

while True:
    nome = input("Digite um nome (ou 'FIM' para encerrar): ")
    if nome.upper() == 'FIM':
        break
    if nome not in nomes:
        nomes.append(nome)

print(f"Lista de nomes: {nomes}")
print(f"Total de nomes diferentes: {len(nomes)}")
# Out:
# Digite um nome (ou 'FIM' para encerrar): maria
# Digite um nome (ou 'FIM' para encerrar): fim]
# Digite um nome (ou 'FIM' para encerrar): FIM
# Lista de nomes: ['maria', 'fim]']
# Total de nomes diferentes: 2

# %% [markdown]
# QUESTÃO 7

# %%
dias = ("Domingo", "Segunda-feira", "Terça-feira", "Quarta-feira", "Quinta-feira", "Sexta-feira", "Sábado")

opcao = int(input("Digite um número de 1 a 7: "))

if 1 <= opcao <= 7:
    print(f"O dia correspondente é: {dias[opcao - 1]}")
else:
    print("Opção inválida.")
# Out:
# Digite um número de 1 a 7: 6
# O dia correspondente é: Sexta-feira

# %% [markdown]
# QUESTÃO 8

# %%
valores = []
for i in range(6):
    num = int(input(f"Digite o {i+1}º número: "))
    valores.append(num)

tupla = tuple(valores)

qtd_cinco = tupla.count(5)
pares = 0
for x in tupla:
    if x % 2 == 0:
        pares += 1

print(f"Tupla: {tupla}")
print(f"O número 5 aparece {qtd_cinco} vez(es).")

if 5 in tupla:
    print(f"A primeira ocorrência do 5 está na posição (índice) {tupla.index(5)}.")
else:
    print("O número 5 não foi digitado.")

print(f"Quantidade de números pares: {pares}")
# Out:
# Digite o 1º número: 9
# Digite o 2º número: 87
# Digite o 3º número: 65
# Digite o 4º número: 43
# Digite o 5º número: 56
# Digite o 6º número: 78
# Tupla: (9, 87, 65, 43, 56, 78)
# O número 5 aparece 0 vez(es).
# O número 5 não foi digitado.
# Quantidade de números pares: 2

# %% [markdown]
# QUESTÃO 9

# %%
aluno = {}
aluno['nome'] = input("Digite o nome: ")
aluno['turma'] = input("Digite a turma: ")
aluno['nota1'] = float(input("Digite a 1ª nota: "))
aluno['nota2'] = float(input("Digite a 2ª nota: "))

aluno['media'] = (aluno['nota1'] + aluno['nota2']) / 2

if aluno['media'] >= 7:
    aluno['situacao'] = 'Aprovado'
elif aluno['media'] >= 5:
    aluno['situacao'] = 'Recuperação'
else:
    aluno['situacao'] = 'Reprovado'

print("\n--- Dados do Aluno ---")
for chave, valor in aluno.items():
    print(f"{chave.capitalize()}: {valor}")
# Out:
# Digite o nome: alice
# Digite a turma: 104-A
# Digite a 1ª nota: 3
# Digite a 2ª nota: 9
#
# --- Dados do Aluno ---
# Nome: alice
# Turma: 104-A
# Nota1: 3.0
# Nota2: 9.0
# Media: 6.0
# Situacao: Recuperação

# %% [markdown]
# QUESTÃO 10

# %%
produtos = {
    "arroz": 25.90,
    "feijão": 8.50,
    "leite": 5.20,
    "café": 14.00,
    "açúcar": 4.30
}

busca = input("Digite o nome do produto para consultar o preço: ").strip().lower()

if busca in produtos:
    print(f"O preço de {busca} é R$ {produtos[busca]:.2f}")
else:
    print("Produto não encontrado no cadastro.")
# Out:
# Digite o nome do produto para consultar o preço: arroz
# O preço de arroz é R$ 25.90

# %% [markdown]
# QUESTÃO 11

# %%
frequencia = {}

for i in range(8):
    palavra = input(f"Digite a {i+1}ª palavra: ").strip().lower()
    if palavra in frequencia:
        frequencia[palavra] += 1
    else:
        frequencia[palavra] = 1

print("\n--- Frequência das Palavras ---")
for palavra, qtd in frequencia.items():
    print(f"'{palavra}': {qtd} vez(es)")
# Out:
# Digite a 1ª palavra: faca
# Digite a 2ª palavra: copo
# Digite a 3ª palavra: colher
# Digite a 4ª palavra: cama
# Digite a 5ª palavra: garrafa
# Digite a 6ª palavra: balde
# Digite a 7ª palavra: bacia
# Digite a 8ª palavra: pano
#
# --- Frequência das Palavras ---
# 'faca': 1 vez(es)
# 'copo': 1 vez(es)
# 'colher': 1 vez(es)
# 'cama': 1 vez(es)
# 'garrafa': 1 vez(es)
# 'balde': 1 vez(es)
# 'bacia': 1 vez(es)
# 'pano': 1 vez(es)

# %% [markdown]
# QUESTÃO 12

# %%
estoque = {
    "caderno": 10,
    "caneta": 50,
    "borracha": 30,
    "mochila": 5
}

prod = input("Digite o nome do produto vendido: ").strip().lower()
qtd_vendida = int(input("Digite a quantidade vendida: "))

if prod in estoque:
    if estoque[prod] >= qtd_vendida:
        estoque[prod] -= qtd_vendida
        print("Venda realizada com sucesso!")
    else:
        print("Erro: Estoque insuficiente.")
else:
    print("Erro: Produto não encontrado no estoque.")

print(f"Estoque final: {estoque}")
# Out:
# Digite o nome do produto vendido: mochila
# Digite a quantidade vendida: 5
# Venda realizada com sucesso!
# Estoque final: {'caderno': 10, 'caneta': 50, 'borracha': 30, 'mochila': 0}

# %% [markdown]
# QUESTÃO 13

# %%
turma = []

for i in range(5):
    print(f"\n--- Cadastro do Aluno {i+1} ---")
    nome = input("Nome: ")
    n1 = float(input("Nota 1: "))
    n2 = float(input("Nota 2: "))
    media = (n1 + n2) / 2

    aluno = {
        "nome": nome,
        "nota1": n1,
        "nota2": n2,
        "media": media
    }
    turma.append(aluno)

print("\n--- Lista de Todos os Alunos ---")
for a in turma:
    print(f"Aluno: {a['nome']} | Média: {a['media']:.2f}")
# Out:
# --- Cadastro do Aluno 1 ---
# Nome: ana
# Nota 1: 5
# Nota 2: 9
#
# --- Cadastro do Aluno 2 ---
# Nome: amanda
# Nota 1: 2
# Nota 2: 8
#
# --- Cadastro do Aluno 3 ---
# Nome: alice
# Nota 1: 8
# Nota 2: 9
#
# --- Cadastro do Aluno 4 ---
# Nome: vitoria
# Nota 1: 3
# Nota 2: 7
#
# --- Cadastro do Aluno 5 ---
# Nome: santos
# Nota 1: 6
# Nota 2: 9
#
# --- Lista de Todos os Alunos ---
# Aluno: ana | Média: 7.00
# Aluno: amanda | Média: 5.00
# Aluno: alice | Média: 8.50
# Aluno: vitoria | Média: 5.00
# Aluno: santos | Média: 7.50

# %% [markdown]
# QUESTÃO 14

# %%
catalogo = []

print("--- Cadastro de 5 Produtos ---")
for i in range(5):
    codigo = int(input(f"Código do produto {i+1}: "))
    nome = input(f"Nome do produto {i+1}: ")
    preco = float(input(f"Preço do produto {i+1}: "))
    produto = (codigo, nome, preco)
    catalogo.append(produto)

cod_busca = int(input("\nDigite o código do produto para buscar: "))
encontrado = False

for prod in catalogo:
    if prod[0] == cod_busca:
        print(f"Produto encontrado: {prod[1]} | Preço: R$ {prod[2]:.2f}")
        encontrado = True
        break

if not encontrado:
    print("Código de produto não encontrado.")
# Out:
# --- Cadastro de 5 Produtos ---
# Código do produto 1: 55567
# Nome do produto 1: caneca
# Preço do produto 1: 700
# Código do produto 2: 567944
# Nome do produto 2: xicara
# Preço do produto 2: 500
# Código do produto 3: 32334
# Nome do produto 3: taça
# Preço do produto 3: 400
# Código do produto 4: 332092300
# Nome do produto 4: garrafa
# Preço do produto 4: 35
# Código do produto 5: 595404
# Nome do produto 5: computador
# Preço do produto 5: 1200
#
# Digite o código do produto para buscar: 595404
# Produto encontrado: computador | Preço: R$ 1200.00

# %% [markdown]
# QUESTÃO 15

# %%
estoque = []

print("--- Cadastro de 5 Itens no Estoque ---")
for i in range(5):
    print(f"\nItem {i+1}:")
    codigo = int(input("Código: "))
    nome = input("Nome: ")
    quantidade = int(input("Quantidade: "))
    preco = float(input("Preço unitário: "))

    item = {
        "codigo": codigo,
        "nome": nome,
        "quantidade": quantidade,
        "preco": preco
    }
    estoque.append(item)

# (a) Mostrar todos os itens
print("\n--- (a) Itens Cadastrados ---")
for item in estoque:
    print(f"Código: {item['codigo']} | Nome: {item['nome']} | Qtd: {item['quantidade']} | Preço: R$ {item['preco']:.2f}")

# (b) Calcular o valor total do estoque e (c) identificar o item de maior valor
valor_total_estoque = 0.0
item_maior_valor = None
maior_valor = -1.0

for item in estoque:
    valor_item = item['quantidade'] * item['preco']
    valor_total_estoque += valor_item

    if valor_item > maior_valor:
        maior_valor = valor_item
        item_maior_valor = item

print(f"\n--- (b) Valor Total do Estoque ---")
print(f"R$ {valor_total_estoque:.2f}")

print(f"\n--- (c) Item de Maior Valor em Estoque (Qtd x Preço) ---")
print(f"Produto: {item_maior_valor['nome']} | Valor Total: R$ {maior_valor:.2f}")

# (d) Criar tupla resumo
tupla_resumo = (len(estoque), valor_total_estoque)

print(f"\n--- (d) Tupla Resumo ---")
print(f"(Qtd de itens cadastrados, Valor total do estoque): {tupla_resumo}")
# Out:
# --- Cadastro de 5 Itens no Estoque ---
#
# Item 1:
# Código: 112233
# Nome: cama
# Quantidade: 2
# Preço unitário: 1500
#
# Item 2:
# Código: 445566
# Nome: cadeira
# Quantidade: 4
# Preço unitário: 45
#
# Item 3:
# Código: 778899
# Nome: mesa
# Quantidade: 1
# Preço unitário: 100
#
# Item 4:
# Código: 001122
# Nome: tv
# Quantidade: 3
# Preço unitário: 5900
#
# Item 5:
# Código: 334455
# Nome: geladeira
# Quantidade: 2
# Preço unitário: 7800
#
# --- (a) Itens Cadastrados ---
# Código: 112233 | Nome: cama | Qtd: 2 | Preço: R$ 1500.00
# Código: 445566 | Nome: cadeira | Qtd: 4 | Preço: R$ 45.00
# Código: 778899 | Nome: mesa | Qtd: 1 | Preço: R$ 100.00
# Código: 1122 | Nome: tv | Qtd: 3 | Preço: R$ 5900.00
# Código: 334455 | Nome: geladeira | Qtd: 2 | Preço: R$ 7800.00
#
# --- (b) Valor Total do Estoque ---
# R$ 36580.00
#
# --- (c) Item de Maior Valor em Estoque (Qtd x Preço) ---
# Produto: tv | Valor Total: R$ 17700.00
#
# --- (d) Tupla Resumo ---
# ...
