# %% [markdown]
# <a href="https://colab.research.google.com/github/alicevitoria4177-arch/-atividade-python/blob/main/Atividade01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Atividade01-Introduçao a python

# %%
print("Ola mundo")
print("Curso Tecnico em informatica")
# Out:
# Ola mundo
# Curso Tecnico em informatica

# %%
disciplina = input("digite o nome da materia: ")
conteudo = input("digite o conteudo estudado: ")
atividade = input("digite o numero da atividade: ")
print("\n---informaçoes da atividade")
print("Diciplina: ,diciplina")
print("Conteudo: ,conteudo")
print("Atividade: ,atividades")
# Out:
# digite o nome da materia: matematica
# digite o conteudo estudado: funçao modular
# digite o numero da atividade: 3
#
# ---informaçoes da atividade
# Diciplina: ,diciplina
# Conteudo: ,conteudo
# Atividade: ,atividade

# %%
numero1 = 10
numero2 = 20
soma = numero1 + numero2
print("Resultado: ",soma)
# Out:
# Resultado:  30

# %%
print("Minha Primeira Atividade no Google colab")
print("Aprendendo python e git hub")
# Out:
# Minha Primeira Atividade no Google colab
# Aprendendo python e git hub

# %%
print("Aprendendo versionamento de projetos")
# Out:
# Aprendendo versionamento de projetos
