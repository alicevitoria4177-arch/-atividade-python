# %% [markdown]
# <a href="https://colab.research.google.com/github/alicevitoria4177-arch/-atividade-python/blob/main/Atividade01_phyton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("ola mundo")
print("curso tecnico em informatica")
# Out:
# ola mundo
# curso tecnico em informatica

# %%
diciplina = input("digite o nome da disciplina: ")
conteudo = input("digite o conteudo estudado: ")
atividade = input("digite o numero da atividade")
# Out:
# digite o nome da disciplina: matematica
# digite o conteudo estudado: funçao modular
# digite o numero da atividade2
